# %% [markdown]
# # Medical Insurance Cost Prediction

# %% [markdown]
# ## importing the modules

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## importing the dataset

# %%
dataset = pd.read_csv("insurance.csv")
dataset.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
dataset.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# ## encoding the catogorial data

# %%
dataset = pd.get_dummies(dataset,drop_first=True)

# %%
print(dataset)
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes  \
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
#       region_northwest  region_southeast  region_southwest
# 0                False             False              True
# 1                False              True             False
# 2                False              True             False
# 3                 True             False             False
# 4                 True             False             False
# ...                ...               ...               ...
# 1333              True             False             False
# 1334             False             False             False
# 1335             False              True             False
# 1336             False             False              True
# 1337              True             False             False
#
# [1338 rows x 9 columns]

# %%
x = dataset.drop("charges", axis=1).values
y = dataset["charges"].values

# %%
print(x)
# Out:
# [[19 27.9 0 ... False False True]
#  [18 33.77 1 ... False True False]
#  [28 33.0 3 ... False True False]
#  ...
#  [18 36.85 0 ... False True False]
#  [21 25.8 0 ... False False True]
#  [61 29.07 0 ... True False False]]

# %%
print(y)
# Out:
# [16884.924   1725.5523  4449.462  ...  1629.8335  2007.945  29141.3603]

# %% [markdown]
# ## spilitting the data into training set and test set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=50)

# %%
print(x_train)
# Out:
# [[18 28.31 1 ... False False False]
#  [18 23.21 0 ... False True False]
#  [54 24.605 3 ... True False False]
#  ...
#  [53 35.9 2 ... False False True]
#  [19 34.7 2 ... False False True]
#  [63 35.09 0 ... False True False]]

# %%
print(x_test)
# Out:
# [[38 30.69 1 ... False True False]
#  [35 43.34 2 ... False True False]
#  [64 40.48 0 ... False True False]
#  ...
#  [62 30.875 3 ... True False False]
#  [25 42.13 1 ... False True False]
#  [48 36.575 0 ... True False False]]

# %% [markdown]
# ## applying feature scalling

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
print(x_train)
# Out:
# [[-1.48073101 -0.37913195 -0.05187531 ... -0.56545278 -0.6084559
#   -0.55162604]
#  [-1.48073101 -1.19665693 -0.89108392 ... -0.56545278  1.64350449
#   -0.55162604]
#  [ 1.08347384 -0.97303981  1.62654191 ...  1.76849428 -0.6084559
#   -0.55162604]
#  ...
#  [ 1.01224593  0.83753759  0.7873333  ... -0.56545278 -0.6084559
#    1.81282233]
#  [-1.4095031   0.64517877  0.7873333  ... -0.56545278 -0.6084559
#    1.81282233]
#  [ 1.72452506  0.70769539 -0.89108392 ... -0.56545278  1.64350449
#   -0.55162604]]

# %%
print(x_test)
# Out:
# [[-0.05617276  0.00237971 -0.05187531 ... -0.56545278  1.64350449
#   -0.55162604]
#  [-0.2698565   2.03016228  0.7873333  ... -0.56545278  1.64350449
#   -0.55162604]
#  [ 1.79575297  1.57170709 -0.89108392 ... -0.56545278  1.64350449
#   -0.55162604]
#  ...
#  [ 1.65329714  0.03203503  1.62654191 ...  1.76849428 -0.6084559
#   -0.55162604]
#  [-0.98213563  1.83620047 -0.05187531 ... -0.56545278  1.64350449
#   -0.55162604]
#  [ 0.65610637  0.94573943 -0.89108392 ...  1.76849428 -0.6084559
#   -0.55162604]]

# %% [markdown]
# ## training the model

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=42)
regressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %% [markdown]
# ## prediction

# %%
from sklearn.metrics import r2_score

y_pred = regressor.predict(x_test)

# %%
print("R2 SCORE:",r2_score(y_test,y_pred))
# Out:
# R2 SCORE: 0.6851888596119851
