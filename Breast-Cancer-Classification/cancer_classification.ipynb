# %% [markdown]
# # Breast-Cancer-Classification

# %% [markdown]
# ## Importing the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## importing the dataset

# %%
dataset = pd.read_csv('Data.csv')
x = dataset.iloc[: ,:-1].values
y = dataset.iloc[: , -1].values

# %%
print(x)

# %%
print(y)

# %% [markdown]
# ## splitting data into tarining set and test set

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=10)

# %% [markdown]
# ## Feature scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train= sc.fit_transform(x_train)
x_test= sc.transform(x_test)

# %% [markdown]
# ## using the K-NN model

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5,metric='minkowski',p=2)
classifier.fit(x_train,y_train)

# %% [markdown]
# ## predict the values

# %%
y_pred = classifier.predict(x_test)

# %%
print(y_pred)
# Out:
# [4 4 2 4 4 4 2 2 4 4 4 2 2 2 4 2 2 4 2 4 2 2 2 2 4 2 2 2 2 2 2 4 4 2 2 4 4
#  4 2 2 4 2 4 2 4 2 2 2 2 2 2 2 2 2 2 2 4 4 2 4 2 4 2 4 2 2 2 2 2 2 2 2 4 2
#  2 2 2 2 2 2 2 2 2 2 4 4 2 2 2 2 4 2 2 2 2 2 2 2 2 2 4 2 4 4 2 2 2 2 4 2 4
#  2 2 4 2 4 4 2 2 2 2 4 2 4 4 2 4 2 4 2 2 2 2 2 4 4 4 4 2 4 4 2 2 2 4 4 2 4
#  2 2 2 4 2 2 2 4 4 2 2 2 2 2 4 2 4 4 2 4 4 2 2]

# %%
print(y_test)
# Out:
# [4 4 4 4 4 4 2 2 4 4 4 2 2 4 4 2 2 4 2 4 2 2 2 2 4 2 2 2 2 2 2 4 4 4 2 4 4
#  4 2 2 4 2 4 2 4 2 2 2 2 2 2 2 2 2 2 2 4 4 2 4 2 4 2 4 2 2 2 2 2 2 2 2 4 2
#  2 2 2 2 2 2 2 2 2 2 4 4 2 2 2 2 4 2 2 2 2 2 2 2 2 2 4 2 4 4 2 2 2 2 4 2 4
#  2 2 4 2 4 4 2 2 2 2 2 2 4 4 4 4 2 4 2 2 2 2 2 4 4 4 4 2 4 4 2 2 2 4 4 2 4
#  2 2 2 4 2 2 2 4 4 2 2 2 2 2 4 2 4 4 2 4 4 2 2]

# %% [markdown]
# ## evaluation using confusion matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[108   1]
#  [  4  58]]

# %% [markdown]
# ## checking the ACCURACY

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9707602339181286
