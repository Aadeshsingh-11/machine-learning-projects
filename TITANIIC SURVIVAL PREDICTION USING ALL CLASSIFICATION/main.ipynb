# %% [markdown]
# # TITANIC SURVIVAL PREDICTION

# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## importing the dataset

# %%
train_set = pd.read_csv("train.csv")
test_set = pd.read_csv("test.csv")

# %%
print(type(train_set))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(train_set.shape)
print(test_set.shape)

# %%
train_set.head()
train_set.columns
train_set.info()

# %%
train_set.isnull().sum()

# %%
test_set.isnull().sum()

# %% [markdown]
# ## dropping the cabin column

# %% [markdown]
# Reason : cabin column contain more the 70% null value

# %%
train_set = train_set.drop(columns=['Cabin'])
test_set  = test_set.drop(columns=['Cabin'])

# %%
'Cabin' in train_set.columns
# Out:
# False

# %%
train_set['Age']=pd.to_numeric(train_set['Age'],errors='coerce')
test_set['Age']=pd.to_numeric(train_set['Age'],errors='coerce')

# %%
age_median = train_set['Age'].median()

train_set['Age'] = train_set['Age'].fillna(age_median)
test_set['Age']  = test_set['Age'].fillna(age_median)

# %%
type(train_set['Age'].isna().sum())
train_set.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
train_set['Age'].apply(type).value_counts()
# Out:
# Age
# <class 'float'>    891
# Name: count, dtype: int64

# %% [markdown]
# using categorian feature on EMBARKED as it contain categorial data

# %%
embarked_mode = train_set['Embarked'].mode()[0]
train_set['Embarked']=train_set['Embarked'].fillna(embarked_mode)
test_set['Embarked']=test_set['Embarked'].fillna(embarked_mode)

# %%
train_set['Embarked'].isna().sum()

# %% [markdown]
# ## Encoding the categorial data

# %%
train_set = pd.get_dummies(train_set,columns=['Sex','Embarked'],drop_first=True)
test_set = pd.get_dummies(test_set,columns=['Sex','Embarked'],drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 train_set = pd.get_dummies(train_set,columns=['Sex','Embarked'],drop_first=True)
#       2 test_set = pd.get_dummies(test_set,columns=['Sex','Embarked'],drop_first=True)
#
# File c:\Users\aades\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\encoding.py:170, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     168     raise TypeError("Input must be a list-like for parameter `columns`")
#     169 else:
# --> 170     data_to_encode = data[columns]
#     172 # validate prefixes and separator to avoid silently dropping cols
#     173 def check_len(item, name: str):
#
# File c:\Users\aades\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\aades\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File c:\Users\aades\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Sex', 'Embarked'], dtype='object')] are in the [columns]"

# %%
train_set.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Sex_male', 'Embarked_Q', 'Embarked_S'],
#       dtype='object')
